# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import geodatasets

# Load the built-in world map dataset from GeoPandas



# Print the list
print("Available built-in datasets in GeoPandas:")
#world = gpd.read_file(gpd.datasets.get_path(geodatasets.get_path('geoda airbnb')))
url = "http://d2ad6b4ur7yvpq.cloudfront.net/naturalearth-3.3.0/ne_110m_land.geojson"
dfc = gpd.read_file(url)

dfc.plot()
ax.set_title('World Map with Data')
ax.set_axis_off()  # Remove axes for a cleaner map
plt.show()
# Out:
# Available built-in datasets in GeoPandas:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 16
#      13 dfc = gpd.read_file(url)
#      15 dfc.plot()
# ---> 16 ax.set_title('World Map with Data')
#      17 ax.set_axis_off()  # Remove axes for a cleaner map
#      18 plt.show()
#
# NameError: name 'ax' is not defined

# %%
# !pip install geodatasets
# Out:
# Collecting geodatasets
#   Using cached geodatasets-2024.8.0-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: pooch in /home/simonray/miniconda3/lib/python3.13/site-packages (from geodatasets) (1.8.2)
# Requirement already satisfied: platformdirs>=2.5.0 in /home/simonray/miniconda3/lib/python3.13/site-packages (from pooch->geodatasets) (4.3.7)
# Requirement already satisfied: packaging>=20.0 in /home/simonray/miniconda3/lib/python3.13/site-packages (from pooch->geodatasets) (24.2)
# Requirement already satisfied: requests>=2.19.0 in /home/simonray/miniconda3/lib/python3.13/site-packages (from pooch->geodatasets) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/simonray/miniconda3/lib/python3.13/site-packages (from requests>=2.19.0->pooch->geodatasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/simonray/miniconda3/lib/python3.13/site-packages (from requests>=2.19.0->pooch->geodatasets) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/simonray/miniconda3/lib/python3.13/site-packages (from requests>=2.19.0->pooch->geodatasets) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in /home/simonray/miniconda3/lib/python3.13/site-packages (from requests>=2.19.0->pooch->geodatasets) (2025.4.26)
# Using cached geodatasets-2024.8.0-py3-none-any.whl (20 kB)
# Installing collected packages: geodatasets
# Successfully installed geodatasets-2024.8.0
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip
